# %%
import pandas as pd
import numpy as np
import plotly as plt
import scipy.optimize as optimize

# %%
df = pd.read_csv("data/USO Historical Data.csv")
avggain = []
avgloss = []
for i in range(len(df['Price']) - 1):
    avg = (df['Price'][i + 1] - df['Price'][i]) / 2
    if avg > 0:
        avggain.append(avg)
    else:
        avgloss.append(avg)
# Out:
# [0.9050000000000011, 1.7749999999999986, 0.9050000000000011, 0.875, 1.0300000000000011, 1.894999999999996, 3.104999999999997, 1.1000000000000014, 0.490000000000002, 0.17499999999999716, 2.105000000000004, 1.7800000000000011, 0.7049999999999983, 4.980000000000004, 0.4450000000000003, 0.2700000000000031, 0.370000000000001, 1.0399999999999991, 0.10500000000000043, 0.5300000000000047, 0.11499999999999488, 0.004999999999999005, 0.33500000000000085, 0.19500000000000028, 0.31999999999999673, 0.25500000000000256, 0.10999999999999943, 0.08000000000000185, 0.370000000000001, 0.4400000000000013, 0.5449999999999982, 0.259999999999998, 0.2950000000000017, 0.6999999999999993, 0.14499999999999957, 0.4349999999999987, 1.1300000000000026, 3.125, 0.16000000000000014, 0.884999999999998, 0.6000000000000014, 0.120000000000001, 0.05000000000000071, 0.8249999999999993, 0.21000000000000085, 1.0949999999999989, 0.125, 0.7750000000000021, 0.10000000000000142, 0.3550000000000004, 0.09499999999999886, 0.0350000
# ...
